# %% [markdown]
# <a href="https://colab.research.google.com/github/purelypurin/project-sme-thai-2565/blob/mainmain/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Load The Dataset
df = pd.read_excel("/content/drive/MyDrive/Data/sme-2565-thai.xlsx","จำนวนผู้ประกอบการ_SME_2565")

# %%
df.head()
# Out:
#   จังหวัด          กลุ่มจังหวัด          ภาคธุรกิจ  \
# 0  กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร
# 1  กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร
# 2  กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร
# 3  กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร
# 4  กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร
#
#    รหัสประเภทธุรกิจ(TSIC-2dg)  \
# 0                         1.0
# 1                         1.0
# 2                         1.0
# 3                         1.0
# 4                         1.0
#
#                     รายละเอียดประเภทธุรกิจ(TSIC-2dg)  \
# 0  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...
# 1  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...
# 2  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...
# 3  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...
# 4  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...
#
#    รหัสประเภทธุรกิจ(TSIC-5dg)       รายละเอียดประเภทธุรกิจ(TSIC-5dg)  \
# 0                      1112.0  การปลูกธัญพืช (ยกเว้น ข้าวและข้าวโพด)
# 1                      1121.0                        การปลูกข้าวเจ้า
# 2                      1131.0      การปลูกพืชผักกินใบและพืชผักกินต้น
# 3                      1131.0      การปลูกพืชผักกินใบและพืชผักกินต้น
# 4                      1136.0                            การเพาะเห็ด
#
#   ขนาดธุรกิจ  จำนวนผู้ประกอบการ ประเภทของข้อมูล    ปี
# 0          S                1.0       นิติบุคคล  2565
# 1      MICRO                2.0   วิสาหกิจชุมชน  2565
# 2      MICRO               23.0   วิสาหกิจชุมชน  2565
# 3          S                1.0       นิติบุคคล  2565
# 4      Micro                1.0       นิติบุคคล  2565

# %%
#Translate Column Names
Translate_Column = {
    'จังหวัด':'Province',
    'กลุ่มจังหวัด':'BusinessRegion',
    'ภาคธุรกิจ':'BusinessSector',
    'รหัสประเภทธุรกิจ(TSIC-2dg)':'BusinessTypeCode_2dg',
    'รายละเอียดประเภทธุรกิจ(TSIC-2dg)':'BusinessTypeDescription_2dg',
    'รหัสประเภทธุรกิจ(TSIC-5dg)':'BusinessTypeCode_5dg',
    'รายละเอียดประเภทธุรกิจ(TSIC-5dg)':'BusinessTypeDescription_5dg',
    'ขนาดธุรกิจ':'BusinessSize',
    'จำนวนผู้ประกอบการ':'NumberOfEntrepreneurs',
    'ประเภทของข้อมูล':'TypeOfData',
    'ปี':'Year'
}

# %%
df.rename(columns=Translate_Column, inplace=True)

# %%
df.head()
# Out:
#   Province        BusinessRegion     BusinessSector  BusinessTypeCode_2dg  \
# 0   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
# 1   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
# 2   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
# 3   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
# 4   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
#
#                          BusinessTypeDescription_2dg  BusinessTypeCode_5dg  \
# 0  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1112.0
# 1  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1121.0
# 2  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1131.0
# 3  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1131.0
# 4  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1136.0
#
#              BusinessTypeDescription_5dg BusinessSize  NumberOfEntrepreneurs  \
# 0  การปลูกธัญพืช (ยกเว้น ข้าวและข้าวโพด)            S                    1.0
# 1                        การปลูกข้าวเจ้า        MICRO                    2.0
# 2      การปลูกพืชผักกินใบและพืชผักกินต้น        MICRO                   23.0
# 3      การปลูกพืชผักกินใบและพืชผักกินต้น            S                    1.0
# 4                            การเพาะเห็ด        Micro                    1.0
#
#       TypeOfData  Year
# 0      นิติบุคคล  2565
# 1  วิสาหกิจชุมชน  2565
# 2  วิสาหกิจชุมชน  2565
# 3      นิติบุคคล  2565
# 4      นิติบุคคล  2565

# %%
#Check NaN
df[df.isna().any(axis=1)]
# Out:
#       Province                    BusinessRegion BusinessSector  \
# 20322  ชัยภูมิ  ภาค ตะวันออกเฉียงเหนือ ตอนล่าง 1            NaN
#
#        BusinessTypeCode_2dg BusinessTypeDescription_2dg  BusinessTypeCode_5dg  \
# 20322                   NaN                         NaN                   NaN
#
#       BusinessTypeDescription_5dg BusinessSize  NumberOfEntrepreneurs  \
# 20322                         NaN          NaN                    NaN
#
#       TypeOfData  Year
# 20322  นิติบุคคล  2565

# %%
#Delete row that have NaN
df.drop(20322, inplace=True)

# %%
#Add Index for Dataframe
df['smeID'] = df.index.astype('int')

# %%
df['smeID']
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 114824    114824
# 114825    114825
# 114826    114826
# 114827    114827
# 114828    114828
# Name: smeID, Length: 114828, dtype: int64

# %%
#Create Dimension Tables
province_dim = df[['Province']].drop_duplicates().reset_index(drop=True)
province_dim['ProvinceID'] = province_dim.index.astype('int')

# %%
province_dim
# Out:
#          Province  ProvinceID
# 0          กระบี่           0
# 1   กรุงเทพมหานคร           1
# 2       กาญจนบุรี           2
# 3       กาฬสินธุ์           3
# 4       กำแพงเพชร           4
# ..            ...         ...
# 72     อำนาจเจริญ          72
# 73       อุดรธานี          73
# 74      อุตรดิตถ์          74
# 75      อุทัยธานี          75
# 76    อุบลราชธานี          76
#
# [77 rows x 2 columns]

# %%
business_region_dim = df[['BusinessRegion']].sort_values(by=['BusinessRegion']).drop_duplicates().reset_index(drop=True)
business_region_dim['BusinessRegionID'] = business_region_dim.index.astype('int')

# %%
business_region_dim
# Out:
#                       BusinessRegion  BusinessRegionID
# 0                      กรุงเทพมหานคร                 0
# 1                     ภาค กลางตอน บน                 1
# 2                 ภาค กลางตอน ล่าง 1                 2
# 3                 ภาค กลางตอน ล่าง 2                 3
# 4                    ภาค กลางปริมณฑล                 4
# 5                     ภาค ตะวันออก 1                 5
# 6                     ภาค ตะวันออก 2                 6
# 7     ภาค ตะวันออกเฉียงเหนือ ตอนกลาง                 7
# 8     ภาค ตะวันออกเฉียงเหนือ ตอนบน 1                 8
# 9     ภาค ตะวันออกเฉียงเหนือ ตอนบน 2                 9
# 10  ภาค ตะวันออกเฉียงเหนือ ตอนล่าง 1                10
# 11  ภาค ตะวันออกเฉียงเหนือ ตอนล่าง 2                11
# 12                 ภาค เหนือ ตอนบน 1                12
# 13                 ภาค เหนือ ตอนบน 2                13
# 14               ภาค เหนือ ตอนล่าง 1                14
# 15               ภาค เหนือ ตอนล่าง 2                15
# 16                    ภาค ใต้ ชายแดน                16
# 17              ภาค ใต้ ฝั่งอันดามัน                17
# 18               ภาค ใต้ ฝั่งอ่าวไทย                18

# %%
business_sector_dim = df[['BusinessSector']].drop_duplicates().reset_index(drop=True)
business_sector_dim['BusinessSectorID'] = business_sector_dim.index.astype('int')

# %%
business_sector_dim
# Out:
#       BusinessSector  BusinessSectorID
# 0  ภาคธุรกิจการเกษตร                 0
# 1         ภาคการผลิต                 1
# 2          ภาคบริการ                 2
# 3          ภาคการค้า                 3

# %%
business_type2dg_dim = df[['BusinessTypeDescription_2dg']].drop_duplicates()
business_type2dg_dim['BusinessTypeCode_2dg'] = df['BusinessTypeCode_2dg'].astype('int')

# %%
business_type5dg_dim = df[['BusinessTypeDescription_5dg']].drop_duplicates()
business_type5dg_dim['BusinessTypeCode_5dg'] = df['BusinessTypeCode_5dg'].astype('int')

# %%
business_type2dg_dim.head()
# Out:
#                           BusinessTypeDescription_2dg  BusinessTypeCode_2dg
# 0   การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                     1
# 58                                  ป่าไม้และการทำไม้                     2
# 60                   การประมงและการเพาะเลี้ยงสัตว์น้ำ                     3
# 69                   การทำเหมืองแร่และเหมืองหินอื่น ๆ                     8
# 72  กิจกรรมบริการที่สนับสนุนการทำเหมืองแร่ และสนับ...                     9

# %%
business_type5dg_dim.head()
# Out:
#                          BusinessTypeDescription_5dg  BusinessTypeCode_5dg
# 0              การปลูกธัญพืช (ยกเว้น ข้าวและข้าวโพด)                  1112
# 1                                    การปลูกข้าวเจ้า                  1121
# 2                  การปลูกพืชผักกินใบและพืชผักกินต้น                  1131
# 4                                        การเพาะเห็ด                  1136
# 6  การปลูกพืชผักอื่น ๆ ซึ่งมิได้จัดประเภทไว้ในที่...                  1139

# %%
business_size_dim = df[['BusinessSize']].drop_duplicates().reset_index(drop=True)
business_size_dim['BusinessSizeID'] = business_size_dim.index.astype('int')

# %%
business_size_dim
# Out:
#   BusinessSize  BusinessSizeID
# 0            S               0
# 1        MICRO               1
# 2        Micro               2
# 3            M               3
# 4            L               4

# %%
#found some error word is the same but type in lowercase
#fix make "Micro" to "MICRO" in dataframe
df['BusinessSize'] = df['BusinessSize'].replace("Micro","MICRO")

# %%
#check "Micro" still in df or not
print(df[df['BusinessSize'].str.contains("Micro", na=False )])
# Out:
# Empty DataFrame
# Columns: [Province, BusinessRegion, BusinessSector, BusinessTypeCode_2dg, BusinessTypeDescription_2dg, BusinessTypeCode_5dg, BusinessTypeDescription_5dg, BusinessSize, NumberOfEntrepreneurs, TypeOfData, Year, smeID]
# Index: []

# %%
#create dimension again
business_size_dim = df[['BusinessSize']].drop_duplicates().reset_index(drop=True)
business_size_dim['BusinessSizeID'] = business_size_dim.index.astype('int')

# %%
business_size_dim
# Out:
#   BusinessSize  BusinessSizeID
# 0            S               0
# 1        MICRO               1
# 2            M               2
# 3            L               3

# %%
type_data_dim = df[['TypeOfData']].drop_duplicates().reset_index(drop=True)
type_data_dim['TypeOfDataID'] = type_data_dim.index.astype('int')

# %%
df.head()
# Out:
#   Province        BusinessRegion     BusinessSector  BusinessTypeCode_2dg  \
# 0   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
# 1   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
# 2   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
# 3   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
# 4   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                   1.0
#
#                          BusinessTypeDescription_2dg  BusinessTypeCode_5dg  \
# 0  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1112.0
# 1  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1121.0
# 2  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1131.0
# 3  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1131.0
# 4  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                1136.0
#
#              BusinessTypeDescription_5dg BusinessSize  NumberOfEntrepreneurs  \
# 0  การปลูกธัญพืช (ยกเว้น ข้าวและข้าวโพด)            S                    1.0
# 1                        การปลูกข้าวเจ้า        MICRO                    2.0
# 2      การปลูกพืชผักกินใบและพืชผักกินต้น        MICRO                   23.0
# 3      การปลูกพืชผักกินใบและพืชผักกินต้น            S                    1.0
# 4                            การเพาะเห็ด        MICRO                    1.0
#
#       TypeOfData  Year  smeID
# 0      นิติบุคคล  2565      0
# 1  วิสาหกิจชุมชน  2565      1
# 2  วิสาหกิจชุมชน  2565      2
# 3      นิติบุคคล  2565      3
# 4      นิติบุคคล  2565      4

# %%
# Map dimension IDs to the fact table
df['ProvinceID'] = df['Province'].map(province_dim.set_index('Province')['ProvinceID'])
df['BusinessRegionID'] = df['BusinessRegion'].map(business_region_dim.set_index('BusinessRegion')['BusinessRegionID'])
df['BusinessSectorID'] = df['BusinessSector'].map(business_sector_dim.set_index('BusinessSector')['BusinessSectorID'])
df['BusinessTypeCode_2dg'] = df['BusinessTypeDescription_2dg'].map(business_type2dg_dim.set_index('BusinessTypeDescription_2dg')['BusinessTypeCode_2dg'])
df['BusinessTypeCode_5dg'] = df['BusinessTypeDescription_5dg'].map(business_type5dg_dim.set_index('BusinessTypeDescription_5dg')['BusinessTypeCode_5dg'])
df['BusinessSizeID'] = df['BusinessSize'].map(business_size_dim.set_index('BusinessSize')['BusinessSizeID'])
df['TypeOfDataID'] = df['TypeOfData'].map(type_data_dim.set_index('TypeOfData')['TypeOfDataID'])

# %%
df.head()
# Out:
#   Province        BusinessRegion     BusinessSector  BusinessTypeCode_2dg  \
# 0   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                     1
# 1   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                     1
# 2   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                     1
# 3   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                     1
# 4   กระบี่  ภาค ใต้ ฝั่งอันดามัน  ภาคธุรกิจการเกษตร                     1
#
#                          BusinessTypeDescription_2dg  BusinessTypeCode_5dg  \
# 0  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                  1112
# 1  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                  1121
# 2  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                  1131
# 3  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                  1131
# 4  การเพาะปลูกและการเลี้ยงสัตว์ การล่าสัตว์และกิจ...                  1136
#
#              BusinessTypeDescription_5dg BusinessSize  NumberOfEntrepreneurs  \
# 0  การปลูกธัญพืช (ยกเว้น ข้าวและข้าวโพด)            S                    1.0
# 1                        การปลูกข้าวเจ้า        MICRO                    2.0
# 2      การปลูกพืชผักกินใบและพืชผักกินต้น        MICRO                   23.0
# 3      การปลูกพืชผักกินใบและพืชผักกินต้น            S                    1.0
# 4                            การเพาะเห็ด        MICRO                    1.0
#
#       TypeOfData  Year  smeID  ProvinceID  BusinessRegionID  BusinessSectorID  \
# 0      นิติบุคคล  2565      0           0                17                 0
# 1  วิสาหกิจชุมชน  2565      1           0                17                 0
# 2  วิสาหกิจชุมชน  2565      2           0                17                 0
# 3      นิติบุคคล  2565      3           0                17                 0
# 4      นิติบุคคล  2565      4           0                17                 0
#
#    BusinessSizeID  TypeOfDataID
# 0               0             0
# 1               1             1
# 2               1             1
# 3               0             0
# 4               1             0

# %%
# Create the fact table
fact_table = df[['smeID','ProvinceID', 'BusinessRegionID', 'BusinessSectorID', 'BusinessTypeCode_2dg', 'BusinessTypeCode_5dg', 'BusinessSizeID', 'TypeOfDataID', 'NumberOfEntrepreneurs', 'Year']]

# %%
fact_table
# Out:
#          smeID  ProvinceID  BusinessRegionID  BusinessSectorID  \
# 0            0           0                17                 0
# 1            1           0                17                 0
# 2            2           0                17                 0
# 3            3           0                17                 0
# 4            4           0                17                 0
# ...        ...         ...               ...               ...
# 114824  114824          76                11                 2
# 114825  114825          76                11                 2
# 114826  114826          76                11                 2
# 114827  114827          76                11                 2
# 114828  114828          76                11                 2
#
#         BusinessTypeCode_2dg  BusinessTypeCode_5dg  BusinessSizeID  \
# 0                          1                  1112               0
# 1                          1                  1121               1
# 2                          1                  1131               1
# 3                          1                  1131               0
# 4                          1                  1136               1
# ...                      ...                   ...             ...
# 114824                    96                 96305               1
# 114825                    96                 96305               0
# 114826                    96                 96309               1
# 114827                    96                 96309               1
# 114828                    96                 96309               0
#
#         TypeOfDataID  NumberOfEntrepreneurs  Year
# 0                  0                    1.0  2565
# 1                  1                    2.0  2565
# 2                  1                   23.0  2565
# 3                  0                    1.0  2565
# 4                  0                    1.0  2565
# ...              ...                    ...   ...
# 114824             0                    1.0  2565
# 114825             2                    1.0  2565
# 114826             0                    5.0  2565
# 114827             2                   41.0  2565
# 114828             2                    2.0  2565
#
# [114828 rows x 10 columns]
